# %% [markdown]
# # ready, add link

# %%
# %pip install ipywidgets sympy mpl-pan-zoom numpy matplotlib ipympl
# Out:
# Requirement already satisfied: ipywidgets in /mnt/nvme/btrfs/yorai/source/viz-playground/interactive_matplotlib/.venv/lib/python3.10/site-packages (8.1.5)
# Requirement already satisfied: sympy in /mnt/nvme/btrfs/yorai/source/viz-playground/interactive_matplotlib/.venv/lib/python3.10/site-packages (1.13.3)
# Requirement already satisfied: mpl-pan-zoom in /mnt/nvme/btrfs/yorai/source/viz-playground/interactive_matplotlib/.venv/lib/python3.10/site-packages (1.0.0)
# Requirement already satisfied: numpy in /mnt/nvme/btrfs/yorai/source/viz-playground/interactive_matplotlib/.venv/lib/python3.10/site-packages (2.1.2)
# Requirement already satisfied: matplotlib in /mnt/nvme/btrfs/yorai/source/viz-playground/interactive_matplotlib/.venv/lib/python3.10/site-packages (3.9.2)
# Requirement already satisfied: ipympl in /mnt/nvme/btrfs/yorai/source/viz-playground/interactive_matplotlib/.venv/lib/python3.10/site-packages (0.9.4)
# Requirement already satisfied: ipython>=6.1.0 in /mnt/nvme/btrfs/yorai/source/viz-playground/interactive_matplotlib/.venv/lib/python3.10/site-packages (from ipywidgets) (8.28.0)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in /mnt/nvme/btrfs/yorai/source/viz-playground/interactive_matplotlib/.venv/lib/python3.10/site-packages (from ipywidgets) (3.0.13)
# Requirement already satisfied: traitlets>=4.3.1 in /mnt/nvme/btrfs/yorai/source/viz-playground/interactive_matplotlib/.venv/lib/python3.10/site-packages (from ipywidgets) (5.14.3)
# Requirement already satisfied: comm>=0.1.3 in /mnt/nvme/btrfs/yorai/source/viz-playground/interactive_matplotlib/.venv/lib/python3.10/site-packages (from ipywidgets) (0.2.2)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in /mnt/nvme/btrfs/yorai/source/viz-playground/interactive_matplotlib/.venv/lib/python3.10/site-packages (from ipywidgets) (4.0.13)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /mnt/nvme/btrfs/yorai/source/viz-playground/interactive_matplotlib/.venv/lib/python3.10/site-packages (from sympy) (1.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /mnt/nvme/btrfs/yorai/source/viz-playground/interactive_matplotlib/.venv/lib/python3.10/site-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: fonttools>=4.22.0 in /mnt/nvme/btrfs/yorai/source/viz-playground/interactive_matplotlib/.venv/lib/python3.10/site-packages (from matplotlib) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /mnt/nvme/btrfs/yorai/source/viz-playground/interactive_matplotlib/.venv/lib/python3.10/site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: contourpy>=1.0.1 in /mnt/nvme/btrfs/yorai/source/viz-playground/interactive_matplotlib/.venv/lib/python3.10/site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: packaging>=20.0 in /mnt/nvme/btrfs/yorai/source/viz-playground/interactive_matplotlib/.venv/lib/python3.10/site-packages (from matplotlib) (24.1)
# Requirement already satisfied: cycler>=0.10 in /mnt/nvme/btrfs/yorai/source/viz-playground/interactive_matplotlib/.venv/lib/python3.10/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: python-dateutil>=2.7 in /mnt/nvme/btrfs/yorai/source/viz-playground/interactive_matplotlib/.venv/lib/python3.10/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pillow>=8 in /mnt/nvme/btrfs/yorai/source/viz-playground/interactive_matplotlib/.venv/lib/python3.10/site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: ipython-genutils in /mnt/nvme/btrfs/yorai/source/viz-playground/interactive_matplotlib/.venv/lib/python3.10/site-packages (from ipympl) (0.2.0)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /mnt/nvme/btrfs/yorai/source/viz-playground/interactive_matplotlib/.venv/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (3.0.48)
# Requirement already satisfied: jedi>=0.16 in /mnt/nvme/btrfs/yorai/source/viz-playground/interactive_matplotlib/.venv/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.19.1)
# Requirement already satisfied: typing-extensions>=4.6 in /mnt/nvme/btrfs/yorai/source/viz-playground/interactive_matplotlib/.venv/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (4.12.2)
# Requirement already satisfied: pygments>=2.4.0 in /mnt/nvme/btrfs/yorai/source/viz-playground/interactive_matplotlib/.venv/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (2.18.0)
# Requirement already satisfied: pexpect>4.3 in /mnt/nvme/btrfs/yorai/source/viz-playground/interactive_matplotlib/.venv/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (4.9.0)
# Requirement already satisfied: decorator in /mnt/nvme/btrfs/yorai/source/viz-playground/interactive_matplotlib/.venv/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: matplotlib-inline in /mnt/nvme/btrfs/yorai/source/viz-playground/interactive_matplotlib/.venv/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.1.7)
# Requirement already satisfied: exceptiongroup in /mnt/nvme/btrfs/yorai/source/viz-playground/interactive_matplotlib/.venv/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (1.2.2)
# Requirement already satisfied: stack-data in /mnt/nvme/btrfs/yorai/source/viz-playground/interactive_matplotlib/.venv/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: six>=1.5 in /mnt/nvme/btrfs/yorai/source/viz-playground/interactive_matplotlib/.venv/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /mnt/nvme/btrfs/yorai/source/viz-playground/interactive_matplotlib/.venv/lib/python3.10/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /mnt/nvme/btrfs/yorai/source/viz-playground/interactive_matplotlib/.venv/lib/python3.10/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: wcwidth in /mnt/nvme/btrfs/yorai/source/viz-playground/interactive_matplotlib/.venv/lib/python3.10/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in /mnt/nvme/btrfs/yorai/source/viz-playground/interactive_matplotlib/.venv/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.1.0)
# Requirement already satisfied: pure-eval in /mnt/nvme/btrfs/yorai/source/viz-playground/interactive_matplotlib/.venv/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.3)
# Requirement already satisfied: asttokens>=2.1.0 in /mnt/nvme/btrfs/yorai/source/viz-playground/interactive_matplotlib/.venv/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.4.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %matplotlib widget
try:
    from google.colab import output
    output.enable_custom_widget_manager()
except:
    pass
import matplotlib.pyplot as plt
import numpy as np
import ipywidgets as widgets
int_slider = widgets.IntSlider(
    value=7,
    min=1,
    max=10,
    step=1,
    description='dim multiplier:',
    orientation='horizontal',
    continuous_update=False,
)
with plt.ioff():
    figure, ax = plt.subplots()
X = data = np.random.random((100,100))
ax_img = ax.imshow(X)

def set_data(event):
    if event['name'] == 'value':
        value = event['new']
    X = data = np.random.random((10*value,10*value))
    ax_img.set_data(X)
    ax.set_title(f'{value}')
    figure.canvas.draw_idle()
int_slider.observe(set_data,names='value')
widgets.VBox([int_slider,figure.canvas])
# Out:
# VBox(children=(IntSlider(value=7, continuous_update=False, description='dim multiplier:', max=10, min=1), Canv…
